# %% [markdown]
# # Start here: a transparent workflow
#
# This project is both a template and a completed example. We will turn one public streamflow query into a documented figure. **You do not need to understand every line on your first run.** Run a cell, read what changes, and ask questions.

# %% [markdown]
# ## What you will make
#
# By the end, `outputs/figures/boulder_creek_streamflow.png` will show daily mean streamflow at one USGS station during summer 2024. It is a descriptive result, not a causal claim or a prediction.

# %%
from pathlib import Path

root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
print(f'Project root: {root}')
assert (root/'environment.yml').exists(), 'Open this notebook from the project folder.'
# Out:
# Project root: c:\Users\gekek\Documents\scientists_who_code_demo_repo

# %% [markdown]
# ## Follow the project map
#
# - `data/raw/`: source responses and provenance; do not edit by hand.
# - `data/processed/`: clean analysis tables created from raw data.
# - `src/`: reusable code.
# - `notebooks/`: the learning narrative.
# - `outputs/`: regenerated figures and tables.
#
# The next notebooks follow a familiar research path: get data → inspect and clean → analyze and visualize → interpret limits.

# %%
for folder in ['data', 'src', 'notebooks', 'outputs', 'docs']:
    print(f'{folder:10} ', 'ready' if (root / folder).exists() else 'missing')
# Out:
# data        ready
# src         ready
# notebooks   ready
# outputs     ready
# docs        ready

# %% [markdown]
# ## Before you continue
#
# This example uses public USGS data. Public access does not remove obligations around sensitive, community, or Tribal data. Read `docs/data-governance.md` before adapting this project to another dataset.
#
# **Next:** open `01_get_open_data.ipynb`.
