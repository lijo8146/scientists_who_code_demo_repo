# %% [markdown]
# # Start here: a transparent workflow
#
# **Goal:** turn one public streamflow query into a documented figure. You do not need to understand every line on your first run. Work through the notebooks in order, ask questions, and notice where each decision is recorded.
#
# Expected result: `outputs/figures/boulder_creek_streamflow.png`, plus a small summary table.
#
# This exemplar is a template demonstration, not a claim about long-term streamflow change or causes.

# %%
from pathlib import Path
root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
print('Project root:', root)
print('Next: open 01_get_open_data.ipynb')
